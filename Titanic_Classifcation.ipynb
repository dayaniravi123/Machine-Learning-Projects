# %% [markdown]
# <a href="https://colab.research.google.com/github/dayaniravi123/Machine-Learning-Projects/blob/main/Titanic_Classifcation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Import required libraries

import tensorflow as tf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_name = "/content/drive/MyDrive/Machine Learning - Tensorflow /Titanic - Classification/train.csv"
file_name
# Out:
# '/content/drive/MyDrive/Machine Learning - Tensorflow /Titanic - Classification/train.csv'

# %%
train_ds = pd.read_csv(file_name)
train_ds.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
## Remove unnessarcy columns from dataset

train_ds = train_ds.drop(columns=['Name', 'Ticket','Cabin','PassengerId'])
train_ds.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
## Convert all the categorical columns into numerical form

train_ds.Sex = train_ds.Sex.astype('category').cat.codes
train_ds.Embarked = train_ds.Embarked.astype('category').cat.codes

# %%
## Plot pairplot of given dataset

sns.pairplot(train_ds)
